# %% [markdown]
# ## Breakout room-1
# ### Group Members:
# #### Muhammad Tabish Sami
# #### Muhammad Sammam Janjua
# #### Ayesha Farooq
# #### Parkash Meghwar
# #### Abdullah Butt

# %% [markdown]
# ### To import libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Attributes are characteristics of an object, while methods are functions that act on an object

# %% [markdown]
# ## To read csv:

# %%
df = pd.read_csv('C:\\Users\\avata\\Desktop\\New folder\\EDA\\Case Study\\COVID clinical trials (1).csv')

df
# Out:
#       Rank   NCT Number                                              Title  \
# 0        1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1        2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2        3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4        5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# ...    ...          ...                                                ...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym                  Status         Study Results  \
# ...

# %% [markdown]
# ## 1. Read Dataset and Explore the dataset by checking shape, columns, see the first/last 'n' rows using head/tail. (n= 5,15,30) (6)

# %% [markdown]
# ### To display shape of the dataset:

# %%
df.shape
# Out:
# (5783, 27)

# %% [markdown]
# ### To display columns of the dataset:

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %% [markdown]
# ### To display first 5 records the dataset:

# %%
df.head(5)
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %% [markdown]
# ### To display first 15 records the dataset:

# %%
df.head(15)
# Out:
#     Rank   NCT Number                                              Title  \
# 0      1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1      2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2      3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3      4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4      5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 5      6  NCT04516954          Convalescent Plasma for COVID-19 Patients
# 6      7  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 7      8  NCT04634214  The Severity of COVID 19 in Diabetes and Non-d...
# 8      9  NCT04602884  Early Detection of COVID-19 Using Breath Analysis
# 9     10  NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
# 10    11  NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 11    12  NCT04412265          Frailty in Elderly Patients With COVID-19
# ...

# %% [markdown]
# ### To display first 30 records the dataset:

# %%
df.head(30)
# Out:
#     Rank   NCT Number                                              Title  \
# 0      1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1      2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2      3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3      4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4      5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 5      6  NCT04516954          Convalescent Plasma for COVID-19 Patients
# 6      7  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 7      8  NCT04634214  The Severity of COVID 19 in Diabetes and Non-d...
# 8      9  NCT04602884  Early Detection of COVID-19 Using Breath Analysis
# 9     10  NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
# 10    11  NCT04355897  CoVID-19 Plasma in Treatment of COVID-19 Patients
# 11    12  NCT04412265          Frailty in Elderly Patients With COVID-19
# ...

# %% [markdown]
# ### To display last 5 records the dataset:

# %%
df.tail(5)
# Out:
#       Rank   NCT Number                                              Title  \
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# 5779  5780  NCT04681339  Antibiotic Prescription in Children Hospitaliz...
# 5780  5781  NCT04740229  Moderate-intensity Flow-based Yoga Effects on ...
# 5781  5782  NCT04804917           3-year Follow-up of the Mind My Mind RCT
# 5782  5783  NCT04680000  Chronic Pain Management In Primary Care Using ...
#
#            Acronym              Status         Study Results  \
# 5778           NaN          Recruiting  No Results Available
# 5779           NaN  Not yet recruiting  No Results Available
# 5780           NaN          Recruiting  No Results Available
# 5781  MindMyMindFU          Recruiting  No Results Available
# 5782           NaN  Not yet recruiting  No Results Available
#
#                                              Conditions  \
# 5778                      Alcohol Drinking|Telemedicine
# ...

# %% [markdown]
# ### To display last 15 records the dataset:

# %%
df.tail(15)
# Out:
#       Rank   NCT Number                                              Title  \
# 5768  5769  NCT04734795  The Prevalence of Dysfunctional Breathing in C...
# 5769  5770  NCT04190368  Team Clinic: Virtual Expansion of an Innovativ...
# 5770  5771  NCT03392883  Scaling Up Science-based Mental Health Interve...
# 5771  5772  NCT04301518  Prematurity Risk Assessment Combined With Clin...
# 5772  5773  NCT04607902  Harnessing Network Science to Personalize Scal...
# 5773  5774  NCT04639661  Predictors of Periodontal Outcomes Post-sanati...
# 5774  5775  NCT04180709  CBT to Reduce Insomnia and Improve Social Reco...
# 5775  5776  NCT04335643  Telehealth CBT for Adolescents and Young Adult...
# 5776  5777  NCT04589377  Mindfulness to Mitigate Psychological Threat a...
# 5777  5778  NCT04574466  Scaling-up Psychological Interventions With Sy...
# 5778  5779  NCT04011644  Mobile Health for Alcohol Use Disorders in Cli...
# ...

# %% [markdown]
# ### To display last 30 records the dataset:

# %%
df.tail(30)
# Out:
#       Rank   NCT Number                                              Title  \
# 5753  5754  NCT04646291  Retrospective Study on the Use, Efficiency, an...
# 5754  5755  NCT04735406                        The MS-LINK™ Outcomes Study
# 5755  5756  NCT02495753  Vaginal Cleansing Before Cesarean Delivery to ...
# 5756  5757  NCT03465280  Airway Intervention Registry (AIR): Recurrent ...
# 5757  5758  NCT04576377  Dynamics of the Immune Responses to Repeat Inf...
# 5758  5759  NCT04713735  Impact of Lactoferrin, a Dietary Supplement, v...
# 5759  5760  NCT03873467  Group Lifestyle Balance™ for Individuals With ...
# 5760  5761  NCT03594734  Group Lifestyle Balance™ for Individuals With ...
# 5761  5762  NCT03728257  Lung Transplant G0 (LTGO): Improving Self-Mana...
# 5762  5763  NCT04782518       Personalizing Exercise for Parkinson Disease
# 5763  5764  NCT04783454  Preventing Neck & Back Pain in Teleworking Off...
# ...

# %% [markdown]
# ## 2. Filter numeric columns and summarize their statistics and do the same for categorical columns(4)

# %% [markdown]
# ### To find the information of columns (i.e. Non-Null Values and Data Type)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %% [markdown]
# ### To find the statistical information of numerical columns

# %%
df.describe()
# Out:
#               Rank    Enrollment
# count  5783.000000  5.749000e+03
# mean   2892.000000  1.831949e+04
# std    1669.552635  4.045437e+05
# min       1.000000  0.000000e+00
# 25%    1446.500000  6.000000e+01
# 50%    2892.000000  1.700000e+02
# 75%    4337.500000  5.600000e+02
# max    5783.000000  2.000000e+07

# %% [markdown]
# ### To find the statistical information of categorical columns

# %%
df.describe(include = 'object')
# Out:
#          NCT Number                                              Title  \
# count          5783                                               5783
# unique         5783                                               5775
# top     NCT04785898  Study Assessing Vagus Nerve Stimulation in CoV...
# freq              1                                                  2
#
#          Acronym      Status         Study Results Conditions  \
# count       2480        5783                  5783       5783
# unique      2338          12                     2       3067
# top     COVID-19  Recruiting  No Results Available   COVID-19
# freq          47        2805                  5747        720
#
#                  Interventions Outcome Measures  \
# count                     4897             5748
# unique                    4337             5687
# top     Other: No intervention        Mortality
# freq                        32                5
#
# ...

# %% [markdown]
# ## 3. Utilize str.strip() to remove leading and trailing spaces and str.replace() to correct specific character issues in the 'Conditions' column of the dataset.

# %% [markdown]
# ### To find column/feature names

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %% [markdown]
# ### Using str.strip() to remove leading and trailing spaces.

# %%
df['Conditions'].str.strip()
# Out:
# 0                                                 Covid19
# 1                                    SARS-CoV-2 Infection
# 2                                                 covid19
# 3                                                   COVID
# 4       Maternal Fetal Infection Transmission|COVID-19...
#                               ...
# 5778                        Alcohol Drinking|Telemedicine
# 5779    Community Acquired Pneumonia in Children|Antib...
# 5780                                 Stress|Psychological
# 5781    Emotional Problem|Anxiety Disorder of Childhoo...
# 5782                                         Chronic Pain
# Name: Conditions, Length: 5783, dtype: object

# %% [markdown]
# ### Using str.replace() to correct specific character issues in the 'Conditions' column of the dataset.

# %%
# Here, we're adding hyphen or "-" in between "Covid" and "19" using .str.replace() function.
df['Conditions'].str.replace('Covid19','Covid-19')
# Out:
# 0                                                Covid-19
# 1                                    SARS-CoV-2 Infection
# 2                                                 covid19
# 3                                                   COVID
# 4       Maternal Fetal Infection Transmission|COVID-19...
#                               ...
# 5778                        Alcohol Drinking|Telemedicine
# 5779    Community Acquired Pneumonia in Children|Antib...
# 5780                                 Stress|Psychological
# 5781    Emotional Problem|Anxiety Disorder of Childhoo...
# 5782                                         Chronic Pain
# Name: Conditions, Length: 5783, dtype: object

# %% [markdown]
# ## 4. Solve following question by using Groupby(10)

# %% [markdown]
# ### i. What is the average enrollment for each status?

# %%
# Grouping the "Status" by finding an average/mean of "Enrollment"
df.groupby(['Status'])['Enrollment'].mean()
# Out:
# Status
# Active, not recruiting       60754.117871
# Approved for marketing                NaN
# Available                             NaN
# Completed                    27826.696585
# Enrolling by invitation      14319.624309
# No longer available                   NaN
# Not yet recruiting           11579.353586
# Recruiting                   10894.446346
# Suspended                     2138.222222
# Temporarily not available             NaN
# Terminated                      74.770270
# Withdrawn                        0.000000
# Name: Enrollment, dtype: float64

# %% [markdown]
# ### ii. How many studies are there for each phase of the trial?

# %%
# Grouping the "Study Results" by finding the counts of "Status"
df.groupby(['Study Results'])['Status'].value_counts()
# Out:
# Study Results         Status
# Has Results           Completed                      33
#                       Terminated                      3
# No Results Available  Recruiting                   2805
#                       Not yet recruiting           1004
#                       Completed                     992
#                       Active, not recruiting        526
#                       Enrolling by invitation       181
#                       Withdrawn                     107
#                       Terminated                     71
#                       Suspended                      27
#                       Available                      19
#                       No longer available            12
#                       Approved for marketing          2
#                       Temporarily not available       1
# Name: count, dtype: int64

# %% [markdown]
# ### iii. What is the average enrollment for studies grouped by gender?

# %%
# Grouping the "Gender" by finding the mean/average of "Enrollment"
df.groupby(['Gender'])['Enrollment'].mean().astype(int) # To make it whole number changed to int
# Out:
# Gender
# All       18984
# Female     1365
# Male        260
# Name: Enrollment, dtype: int32

# %% [markdown]
# ### What is the earliest start date for each study type?

# %%
# To change date into date-type format.
df['Start Date']= pd.to_datetime(df['Start Date'],format='mixed')

# %%
# Grouping 'Study Type' by finding minimum date for each start date.
df.groupby(['Study Type'])['Start Date'].min()
# Out:
# Study Type
# Expanded Access                                                              NaT
# Expanded Access:Individual Patients                                          NaT
# Expanded Access:Individual Patients|Intermediate-size Population             NaT
# Expanded Access:Individual Patients|Treatment IND/Protocol                   NaT
# Expanded Access:Intermediate-size Population                                 NaT
# Expanded Access:Intermediate-size Population|Treatment IND/Protocol          NaT
# Expanded Access:Treatment IND/Protocol                                       NaT
# Interventional                                                        2011-02-02
# Observational                                                         1998-01-01
# Name: Start Date, dtype: datetime64[ns]

# %%
# df[df['Study Type'] == 'Expanded Access']

# %%
# What is the distribution of statuses in the dataset?
df['Status'].value_counts()
# Out:
# Status
# Recruiting                   2805
# Completed                    1025
# Not yet recruiting           1004
# Active, not recruiting        526
# Enrolling by invitation       181
# Withdrawn                     107
# Terminated                     74
# Suspended                      27
# Available                      19
# No longer available            12
# Approved for marketing          2
# Temporarily not available       1
# Name: count, dtype: int64

# %% [markdown]
# # 5. Solve following question by using qcut(10)
# ###### Enrollment Quantile Categories: How are trials distributed across four quantiles based on enrollment numbers?
# ###### Start Date Year Quantiles: What are the time periods represented by four quantiles of trial start years?
# ###### Completion Time Frame Categories: How do trial durations distribute across four quantiles from start to completion date?
# ###### Outcome Measures Count Quantiles: How are trials categorized into four quantiles based on the number of outcome measures?
# ###### Trial Update Frequency Quantiles: What does the distribution of trial update frequencies look like across four quantiles?

# %% [markdown]
# ### i. Enrollment Quantile Categories: How are trials distributed across four quantiles based on enrollment numbers?

# %%
df['Enrollment1'] = pd.qcut(df['Enrollment'], q=4)
print(df[['Enrollment', 'Enrollment1']])
# Out:
#       Enrollment          Enrollment1
# 0         1000.0  (560.0, 20000000.0]
# 1           60.0       (-0.001, 60.0]
# 2          500.0       (170.0, 560.0]
# 3         2500.0  (560.0, 20000000.0]
# 4           50.0       (-0.001, 60.0]
# ...          ...                  ...
# 5778       566.0  (560.0, 20000000.0]
# 5779       200.0       (170.0, 560.0]
# 5780        88.0        (60.0, 170.0]
# 5781       396.0       (170.0, 560.0]
# 5782       716.0  (560.0, 20000000.0]
#
# [5783 rows x 2 columns]

# %%
df['Enrollment1'].value_counts().sort_index()
# Out:
# Enrollment1
# (-0.001, 60.0]         1562
# (60.0, 170.0]          1313
# (170.0, 560.0]         1438
# (560.0, 20000000.0]    1436
# Name: count, dtype: int64

# %% [markdown]
# ### ii. Start Date Year Quantiles: What are the time periods represented by four quantiles of trial start years?

# %%
df['Start Year'] = pd.qcut(df['Start Date'], q=4)
print(df[['Start Year', 'Start Date']])
# Out:
#                                        Start Year Start Date
# 0                        (2020-07-01, 2020-11-20] 2020-11-09
# 1                        (2020-07-01, 2020-11-20] 2020-11-02
# 2                        (2020-04-24, 2020-07-01] 2020-05-07
# 3                        (2020-04-24, 2020-07-01] 2020-05-25
# 4                        (2020-04-24, 2020-07-01] 2020-05-05
# ...                                           ...        ...
# 5778  (1997-12-31 23:59:59.999999999, 2020-04-24] 2020-03-23
# 5779                     (2020-11-20, 2022-01-01] 2021-04-01
# 5780                     (2020-11-20, 2022-01-01] 2021-02-10
# 5781                     (2020-11-20, 2022-01-01] 2021-03-22
# 5782                     (2020-11-20, 2022-01-01] 2021-02-01
#
# [5783 rows x 2 columns]

# %% [markdown]
# ### iii. Completion Time Frame Categories: How do trial durations distribute across four quantiles from start to completion date?

# %%
# To transform 'Completion Date' into date data-type:
df['Completion Date']= pd.to_datetime(df['Completion Date'],format='mixed')

# %%
# To take difference of dates to find total duration:
df['Duration'] = ((df['Completion Date'] - df['Start Date'])/np.timedelta64(1, 'D'))
df['Duration']
# Out:
# 0        172.0
# 1         88.0
# 2        404.0
# 3         98.0
# 4        361.0
#          ...
# 5778    1104.0
# 5779    1340.0
# 5780     141.0
# 5781     649.0
# 5782    1461.0
# Name: Duration, Length: 5783, dtype: float64

# %%
# To make quantiles using qcut 
df['Duration1'] = pd.qcut(df['Duration'], q=4)
print(df[['Duration1', 'Duration']])
# Out:
#              Duration1  Duration
# 0       (139.0, 293.0]     172.0
# 1      (-0.001, 139.0]      88.0
# 2       (293.0, 497.0]     404.0
# 3      (-0.001, 139.0]      98.0
# 4       (293.0, 497.0]     361.0
# ...                ...       ...
# 5778  (497.0, 29119.0]    1104.0
# 5779  (497.0, 29119.0]    1340.0
# 5780    (139.0, 293.0]     141.0
# 5781  (497.0, 29119.0]     649.0
# 5782  (497.0, 29119.0]    1461.0
#
# [5783 rows x 2 columns]

# %% [markdown]
# ### iv. Outcome Measures Count Quantiles: How are trials categorized into four quantiles based on the number of outcome measures?

# %%
df['Outcome Measures'].value_counts()
Trails_Outcome = df['Outcome Measures'].str.count('|') + 1
df['Trails Outcome'] = pd.qcut(Trails_Outcome, q=4)
print(df[['Trails Outcome', 'Outcome Measures']])
# Out:
#         Trails Outcome                                   Outcome Measures
# 0        (93.0, 210.0]  Evaluate the diagnostic performance of the ID ...
# 1        (4.999, 93.0]  Change on viral load results from baseline aft...
# 2     (436.0, 11711.0]  A qualitative analysis of parenchymal lung dam...
# 3        (93.0, 210.0]  Proportion of asymptomatic subjects|Proportion...
# 4        (93.0, 210.0]  COVID-19 by positive PCR in cord blood and / o...
# ...                ...                                                ...
# 5778  (436.0, 11711.0]  Number of risky drinking days|Number of patien...
# 5779  (436.0, 11711.0]  Antibiotic treatment rates in hospitalized chi...
# 5780     (93.0, 210.0]  Perceived Stress|Task switching paradigm|Digit...
# 5781    (210.0, 436.0]  The child's impact of mental health problems r...
# 5782    (210.0, 436.0]  Defense and Veterans Pain Rating Scale (DVPRS)...
#
# [5783 rows x 2 columns]

# %%
df['Trails Outcome'].value_counts().sort_index()
# Out:
# Trails Outcome
# (4.999, 93.0]       1439
# (93.0, 210.0]       1438
# (210.0, 436.0]      1436
# (436.0, 11711.0]    1435
# Name: count, dtype: int64

# %% [markdown]
# ### v. Trial Update Frequency Quantiles: What does the distribution of trial update frequencies look like across four quantiles?

# %%
df['Last Update Posted']= pd.to_datetime(df['Last Update Posted'],format='mixed')
df['Results First Posted']= pd.to_datetime(df['Results First Posted'],format='mixed')

# %%
df['Update Frequency'] = pd.qcut(df['Last Update Posted'], q=4)
print(df[['Update Frequency', 'Last Update Posted']])
# Out:
#                                  Update Frequency Last Update Posted
# 0                        (2021-02-26, 2021-04-14]         2021-03-08
# 1                        (2020-08-11, 2020-12-14]         2020-10-20
# 2                        (2020-08-11, 2020-12-14]         2020-11-09
# 3     (2020-02-04 23:59:59.999999999, 2020-08-11]         2020-06-04
# 4     (2020-02-04 23:59:59.999999999, 2020-08-11]         2020-06-04
# ...                                           ...                ...
# 5778                     (2021-02-26, 2021-04-14]         2021-04-02
# 5779                     (2020-12-14, 2021-02-26]         2021-02-10
# 5780                     (2020-12-14, 2021-02-26]         2021-02-24
# 5781                     (2021-02-26, 2021-04-14]         2021-04-01
# 5782                     (2020-12-14, 2021-02-26]         2020-12-22
#
# [5783 rows x 2 columns]

# %% [markdown]
# ## 6. Completion Time Frame Grouping: Apply the cut function to categorize the completion time frames of trials into distinct intervals. What are the characteristics of trials within each time frame group?

# %%
# To create bins
bins = [0, 30, 60, 90, 120, float('inf')]
# To create labels
labels = ['0-30 days', '31-60 days', '61-90 days', '91-120 days', 'Over 120 days']
# Using cut
df['Completion Time Frame'] = pd.cut(df['Duration'], bins = bins, labels = labels)

print(df[['Completion Time Frame','Duration']])
# Out:
#      Completion Time Frame  Duration
# 0            Over 120 days     172.0
# 1               61-90 days      88.0
# 2            Over 120 days     404.0
# 3              91-120 days      98.0
# 4            Over 120 days     361.0
# ...                    ...       ...
# 5778         Over 120 days    1104.0
# 5779         Over 120 days    1340.0
# 5780         Over 120 days     141.0
# 5781         Over 120 days     649.0
# 5782         Over 120 days    1461.0
#
# [5783 rows x 2 columns]

# %% [markdown]
# ### Observation:
# <p><b>0-30 days:</b> No trials fall within this time frame group.</p>
# <p><b>31-60 days:</b> No trials fall within this time frame group.</p>
# <p><b>61-90 days:</b> Some trials fall within this time frame group, with durations upto <b>98 days.</b></p>
# <p><b>91-120 days:</b> Some trials fall within this time frame group, with durations upto <b>98 days.</b></p>
# <p><b>Over 120 days:</b> The majority of trials fall within this time frame group, with durations exceeding <b>120 days</b>. Durations in this group range from <b>172</b> to <b>1461 days.</b></p>
#
# <p>These characteristics suggest that a significant portion of trials have durations extending beyond <b>120 days</b>, while fewer trials fall within the shorter time frame groups of <b>61-90 days</b> and <b>91-120 days.</b></p>
# <p>Additionally, no trials are recorded within the first two time frame groups <b>(0-30 days and 31-60 days)</b> in the provided data snippet.</p>

# %%
df['Completion Time Frame'].value_counts()
# Out:
# Completion Time Frame
# Over 120 days    4531
# 61-90 days        354
# 91-120 days       337
# 31-60 days        291
# 0-30 days         211
# Name: count, dtype: int64

# %% [markdown]
# ## 7. Enrollment Distribution Analysis: Use Matplotlib's hist() function to create a histogram visualizing the distribution of the 'Enrollment' column in the dataset.

# %%
df['Enrollment']
# Out:
# 0       1000.0
# 1         60.0
# 2        500.0
# 3       2500.0
# 4         50.0
#          ...
# 5778     566.0
# 5779     200.0
# 5780      88.0
# 5781     396.0
# 5782     716.0
# Name: Enrollment, Length: 5783, dtype: float64

# %%
plt.hist(df['Enrollment'])

# Adding labels and title
plt.xlabel('Enrollment')
plt.ylabel('Frequency')
plt.title('Enrollment Distribution')

# Displaying the plot
plt.show()

# %% [markdown]
# ### Used numpy log function to visualize all data points.

# %%
# Apply logarithmic transformation to enrollment data
log_enrollment = np.log1p(df['Enrollment'])

# Plot histogram with logarithmic transformation
plt.hist(log_enrollment, bins=20, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Log(Enrollment)')
plt.ylabel('Frequency')
plt.title('Logarithmic Enrollment Distribution')

# Displaying the plot
plt.show()
